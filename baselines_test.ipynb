# %%
from RLSwitch import RLSwitchEnv
from stable_baselines3 import A2C,DQN,PPO
from stable_baselines3.common.env_checker import check_env
import numpy as np

# %%
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm
from maxWeight import maxWeight

# %%
n = 3
end_t = 1000000
env =  RLSwitchEnv(n,end_t, lambdaMatrix = None)
ppoAgent = PPO('MlpPolicy',env,verbose=1)
ppoAgent.learn(total_timesteps=100000)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 1458         |
# |    iterations           | 1            |
# |    time_elapsed         | 1            |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0012685941 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | -1.93e+07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.3e+04      |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0047      |
# |    value_loss           | 1.48e+05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 1064        |
# |    iterations           | 2           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.005977171 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -8.45e+04   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.11e+04    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00381    |
# |    value_loss           | 1.78e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 984         |
# |    iterations           | 3           |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.007342754 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -4.04e+05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.83e+04    |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00763    |
# |    value_loss           | 1.62e+05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 942         |
# |    iterations           | 4           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.006460935 |
# |    clip_fraction        | 0.0156      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.79       |
# |    explained_variance   | -1.61e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58e+05    |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00605    |
# |    value_loss           | 3.21e+05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 905          |
# |    iterations           | 5            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0030658403 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.78        |
# |    explained_variance   | -1.65e+07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.54e+04     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00653     |
# |    value_loss           | 1.33e+05     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 891        |
# |    iterations           | 6          |
# |    time_elapsed         | 13         |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.00782832 |
# |    clip_fraction        | 0.0469     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.78      |
# |    explained_variance   | -2.44e+07  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.04e+05   |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.00678   |
# |    value_loss           | 2.14e+05   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 877          |
# |    iterations           | 7            |
# |    time_elapsed         | 16           |
# |    total_timesteps      | 14336        |
# | train/                  |              |
# |    approx_kl            | 0.0029833503 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | -1.17e+07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.43e+04     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.00337     |
# |    value_loss           | 1.39e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 864          |
# |    iterations           | 8            |
# |    time_elapsed         | 18           |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.0032098927 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | -3.24e+08    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.29e+04     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.00527     |
# |    value_loss           | 1.24e+05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 861          |
# |    iterations           | 9            |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0057575866 |
# |    clip_fraction        | 0.0312       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.77        |
# |    explained_variance   | -9.21e+06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.17e+04     |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00514     |
# |    value_loss           | 8.98e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 859         |
# |    iterations           | 10          |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.012706515 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | -2.56e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.5e+04     |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00811    |
# |    value_loss           | 9.16e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 856         |
# |    iterations           | 11          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006289443 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.76       |
# |    explained_variance   | -1.25e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.32e+04    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.00611    |
# |    value_loss           | 7.04e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 850          |
# |    iterations           | 12           |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 24576        |
# | train/                  |              |
# |    approx_kl            | 0.0034388795 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.75        |
# |    explained_variance   | -4.71e+07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.75e+04     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.00667     |
# |    value_loss           | 7.95e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 849          |
# |    iterations           | 13           |
# |    time_elapsed         | 31           |
# |    total_timesteps      | 26624        |
# | train/                  |              |
# |    approx_kl            | 0.0107644815 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.74        |
# |    explained_variance   | -2.43e+07    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.77e+04     |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.00526     |
# |    value_loss           | 9.6e+04      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 848         |
# |    iterations           | 14          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.008070545 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | -6.08e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.98e+04    |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00562    |
# |    value_loss           | 8.44e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 847         |
# |    iterations           | 15          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.010038478 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.73       |
# |    explained_variance   | -5.82e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.13e+04    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.00706    |
# |    value_loss           | 6.14e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 846          |
# |    iterations           | 16           |
# |    time_elapsed         | 38           |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0079728495 |
# |    clip_fraction        | 0.125        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | -4.44e+08    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.06e+04     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.00834     |
# |    value_loss           | 6.06e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 845          |
# |    iterations           | 17           |
# |    time_elapsed         | 41           |
# |    total_timesteps      | 34816        |
# | train/                  |              |
# |    approx_kl            | 0.0067466977 |
# |    clip_fraction        | 0.109        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.73        |
# |    explained_variance   | -2.73e+06    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.73e+04     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -0.00839     |
# |    value_loss           | 5.12e+04     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 18           |
# |    time_elapsed         | 43           |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0106213875 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.72        |
# |    explained_variance   | -2.11e+08    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.09e+04     |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00812     |
# |    value_loss           | 5.14e+04     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 843        |
# |    iterations           | 19         |
# |    time_elapsed         | 46         |
# |    total_timesteps      | 38912      |
# | train/                  |            |
# |    approx_kl            | 0.01018547 |
# |    clip_fraction        | 0.0938     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.71      |
# |    explained_variance   | -2.36e+08  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.02e+04   |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.00946   |
# |    value_loss           | 4.07e+04   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 842          |
# |    iterations           | 20           |
# |    time_elapsed         | 48           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0059474455 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.7         |
# |    explained_variance   | -3.86e+08    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.73e+04     |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00716     |
# |    value_loss           | 3.81e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 841         |
# |    iterations           | 21          |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.005877194 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.71       |
# |    explained_variance   | -1.23e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.71e+04    |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 3.62e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 22          |
# |    time_elapsed         | 53          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.008209707 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | -1.29e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.35e+04    |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00913    |
# |    value_loss           | 2.86e+04    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 840          |
# |    iterations           | 23           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0060308697 |
# |    clip_fraction        | 0.0781       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | -9.69e+08    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04e+04     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.0117      |
# |    value_loss           | 3.9e+04      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 24          |
# |    time_elapsed         | 58          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008841206 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.66       |
# |    explained_variance   | -2.35e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.72e+04    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00876    |
# |    value_loss           | 3.13e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 25          |
# |    time_elapsed         | 61          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009146283 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.65       |
# |    explained_variance   | -2.58e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39e+04    |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 2.92e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 26          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.009127637 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.64       |
# |    explained_variance   | -8.62e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.01e+04    |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 2.43e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 27          |
# |    time_elapsed         | 66          |
# |    total_timesteps      | 55296       |
# | train/                  |             |
# |    approx_kl            | 0.003930259 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.62       |
# |    explained_variance   | -7.64e+06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.74e+04    |
# |    n_updates            | 260         |
# |    policy_gradient_loss | -0.00991    |
# |    value_loss           | 3.08e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 28          |
# |    time_elapsed         | 68          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.010704245 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.61       |
# |    explained_variance   | -9.83e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.39e+04    |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.00946    |
# |    value_loss           | 2.71e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 29          |
# |    time_elapsed         | 70          |
# |    total_timesteps      | 59392       |
# | train/                  |             |
# |    approx_kl            | 0.003106013 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.59       |
# |    explained_variance   | -1.23e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.05e+03    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -0.00941    |
# |    value_loss           | 1.86e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 30          |
# |    time_elapsed         | 73          |
# |    total_timesteps      | 61440       |
# | train/                  |             |
# |    approx_kl            | 0.010326647 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.58       |
# |    explained_variance   | -1.97e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1e+04       |
# |    n_updates            | 290         |
# |    policy_gradient_loss | -0.0107     |
# |    value_loss           | 2.59e+04    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 836        |
# |    iterations           | 31         |
# |    time_elapsed         | 75         |
# |    total_timesteps      | 63488      |
# | train/                  |            |
# |    approx_kl            | 0.00878183 |
# |    clip_fraction        | 0.0625     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.57      |
# |    explained_variance   | -2.03e+08  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.34e+04   |
# |    n_updates            | 300        |
# |    policy_gradient_loss | -0.00719   |
# |    value_loss           | 2.95e+04   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 32          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.009772129 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.55       |
# |    explained_variance   | -8.03e+06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.79e+03    |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0114     |
# |    value_loss           | 1.3e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 33          |
# |    time_elapsed         | 80          |
# |    total_timesteps      | 67584       |
# | train/                  |             |
# |    approx_kl            | 0.008968255 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.54       |
# |    explained_variance   | -1.72e+09   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.18e+04    |
# |    n_updates            | 320         |
# |    policy_gradient_loss | -0.00868    |
# |    value_loss           | 2.29e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 34          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.017115451 |
# |    clip_fraction        | 0.156       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.53       |
# |    explained_variance   | -3.12e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.1e+03     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.0144     |
# |    value_loss           | 1.72e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 35          |
# |    time_elapsed         | 85          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.008930091 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.52       |
# |    explained_variance   | -8.81e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.69e+03    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.0105     |
# |    value_loss           | 1.6e+04     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 36          |
# |    time_elapsed         | 88          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.008119061 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.49       |
# |    explained_variance   | -4.78e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.84e+03    |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0129     |
# |    value_loss           | 1.41e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 37          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.018775117 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.46       |
# |    explained_variance   | -7.49e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.21e+03    |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 1.43e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 38          |
# |    time_elapsed         | 93          |
# |    total_timesteps      | 77824       |
# | train/                  |             |
# |    approx_kl            | 0.010008739 |
# |    clip_fraction        | 0.141       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.44       |
# |    explained_variance   | -6.41e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.26e+03    |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0102     |
# |    value_loss           | 9.3e+03     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 39           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 79872        |
# | train/                  |              |
# |    approx_kl            | 0.0073697874 |
# |    clip_fraction        | 0.0469       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.44        |
# |    explained_variance   | -2.04e+08    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6e+03        |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00956     |
# |    value_loss           | 1.34e+04     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 40          |
# |    time_elapsed         | 97          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.009697401 |
# |    clip_fraction        | 0.0312      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.41       |
# |    explained_variance   | -3.31e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.79e+03    |
# |    n_updates            | 390         |
# |    policy_gradient_loss | -0.0117     |
# |    value_loss           | 1.35e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 41          |
# |    time_elapsed         | 100         |
# |    total_timesteps      | 83968       |
# | train/                  |             |
# |    approx_kl            | 0.006578748 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.4        |
# |    explained_variance   | -1.84e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.63e+03    |
# |    n_updates            | 400         |
# |    policy_gradient_loss | -0.0124     |
# |    value_loss           | 1.18e+04    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 42          |
# |    time_elapsed         | 102         |
# |    total_timesteps      | 86016       |
# | train/                  |             |
# |    approx_kl            | 0.011775887 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -5.16e+06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.71e+03    |
# |    n_updates            | 410         |
# |    policy_gradient_loss | -0.0113     |
# |    value_loss           | 9.9e+03     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 43          |
# |    time_elapsed         | 105         |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.016253246 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.36       |
# |    explained_variance   | -8.16e+08   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 5.28e+03    |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.0123     |
# |    value_loss           | 9.16e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 44          |
# |    time_elapsed         | 107         |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.012378557 |
# |    clip_fraction        | 0.0938      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.35       |
# |    explained_variance   | -4.69e+06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.89e+03    |
# |    n_updates            | 430         |
# |    policy_gradient_loss | -0.0103     |
# |    value_loss           | 6.43e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 836         |
# |    iterations           | 45          |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.013363405 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | -6.43e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.39e+03    |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.014      |
# |    value_loss           | 9.06e+03    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 837          |
# |    iterations           | 46           |
# |    time_elapsed         | 112          |
# |    total_timesteps      | 94208        |
# | train/                  |              |
# |    approx_kl            | 0.0068128724 |
# |    clip_fraction        | 0.0625       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.32        |
# |    explained_variance   | -1.74e+09    |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.6e+03      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -0.00858     |
# |    value_loss           | 6.95e+03     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 47          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 96256       |
# | train/                  |             |
# |    approx_kl            | 0.008668371 |
# |    clip_fraction        | 0.0625      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | -4.48e+07   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.81e+03    |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 7.93e+03    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 837         |
# |    iterations           | 48          |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011453486 |
# |    clip_fraction        | 0.0781      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.28       |
# |    explained_variance   | -2.89e+09   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.9e+03     |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0101     |
# |    value_loss           | 6.29e+03    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 837        |
# |    iterations           | 49         |
# |    time_elapsed         | 119        |
# |    total_timesteps      | 100352     |
# | train/                  |            |
# |    approx_kl            | 0.01133592 |
# |    clip_fraction        | 0.0938     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.27      |
# |    explained_variance   | -8.38e+09  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.84e+03   |
# |    n_updates            | 480        |
# |    policy_gradient_loss | -0.0121    |
# |    value_loss           | 7.83e+03   |
# ----------------------------------------

# %%
n = 3
end_t = 1000000
env =  RLSwitchEnv(n,end_t, lambdaMatrix = None)
dqnAgent = DQN('MlpPolicy',env,
               buffer_size= 10,
               verbose=1)
dqnAgent.learn(total_timesteps=1000000)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# -------------------------------------
# | rollout/              |           |
# |    exploration rate   | 0.962     |
# | time/                 |           |
# |    episodes           | 4         |
# |    fps                | 1843      |
# |    time_elapsed       | 2         |
# |    total timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -1.42     |
# |    explained_variance | -3.08e+13 |
# |    learning_rate      | 0.0001    |
# |    n_updates          | 987       |
# |    policy_loss        | 177       |
# |    value_loss         | 1.44e+05  |
# -------------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.924    |
# | time/               |          |
# |    episodes         | 8        |
# |    fps              | 1807     |
# |    time_elapsed     | 4        |
# |    total timesteps  | 8000     |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 1987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.886    |
# | time/               |          |
# |    episodes         | 12       |
# |    fps              | 1792     |
# |    time_elapsed     | 6        |
# |    total timesteps  | 12000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 2987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.848    |
# | time/               |          |
# |    episodes         | 16       |
# |    fps              | 1771     |
# |    time_elapsed     | 9        |
# |    total timesteps  | 16000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 3987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.81     |
# | time/               |          |
# |    episodes         | 20       |
# |    fps              | 1734     |
# |    time_elapsed     | 11       |
# |    total timesteps  | 20000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 4987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.772    |
# | time/               |          |
# |    episodes         | 24       |
# |    fps              | 1725     |
# |    time_elapsed     | 13       |
# |    total timesteps  | 24000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 5987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.734    |
# | time/               |          |
# |    episodes         | 28       |
# |    fps              | 1713     |
# |    time_elapsed     | 16       |
# |    total timesteps  | 28000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 6987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.696    |
# | time/               |          |
# |    episodes         | 32       |
# |    fps              | 1696     |
# |    time_elapsed     | 18       |
# |    total timesteps  | 32000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 7987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.658    |
# | time/               |          |
# |    episodes         | 36       |
# |    fps              | 1673     |
# |    time_elapsed     | 21       |
# |    total timesteps  | 36000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 8987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.62     |
# | time/               |          |
# |    episodes         | 40       |
# |    fps              | 1664     |
# |    time_elapsed     | 24       |
# |    total timesteps  | 40000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 9987     |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.582    |
# | time/               |          |
# |    episodes         | 44       |
# |    fps              | 1652     |
# |    time_elapsed     | 26       |
# |    total timesteps  | 44000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 10987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.544    |
# | time/               |          |
# |    episodes         | 48       |
# |    fps              | 1642     |
# |    time_elapsed     | 29       |
# |    total timesteps  | 48000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 11987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.506    |
# | time/               |          |
# |    episodes         | 52       |
# |    fps              | 1631     |
# |    time_elapsed     | 31       |
# |    total timesteps  | 52000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 12987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.468    |
# | time/               |          |
# |    episodes         | 56       |
# |    fps              | 1620     |
# |    time_elapsed     | 34       |
# |    total timesteps  | 56000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 13987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.43     |
# | time/               |          |
# |    episodes         | 60       |
# |    fps              | 1608     |
# |    time_elapsed     | 37       |
# |    total timesteps  | 60000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 14987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.392    |
# | time/               |          |
# |    episodes         | 64       |
# |    fps              | 1597     |
# |    time_elapsed     | 40       |
# |    total timesteps  | 64000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 15987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.354    |
# | time/               |          |
# |    episodes         | 68       |
# |    fps              | 1585     |
# |    time_elapsed     | 42       |
# |    total timesteps  | 68000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 16987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.316    |
# | time/               |          |
# |    episodes         | 72       |
# |    fps              | 1575     |
# |    time_elapsed     | 45       |
# |    total timesteps  | 72000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 17987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.278    |
# | time/               |          |
# |    episodes         | 76       |
# |    fps              | 1565     |
# |    time_elapsed     | 48       |
# |    total timesteps  | 76000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 18987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.24     |
# | time/               |          |
# |    episodes         | 80       |
# |    fps              | 1555     |
# |    time_elapsed     | 51       |
# |    total timesteps  | 80000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 19987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.202    |
# | time/               |          |
# |    episodes         | 84       |
# |    fps              | 1545     |
# |    time_elapsed     | 54       |
# |    total timesteps  | 84000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 20987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.164    |
# | time/               |          |
# |    episodes         | 88       |
# |    fps              | 1535     |
# |    time_elapsed     | 57       |
# |    total timesteps  | 88000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 21987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.126    |
# | time/               |          |
# |    episodes         | 92       |
# |    fps              | 1524     |
# |    time_elapsed     | 60       |
# |    total timesteps  | 92000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 22987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.088    |
# | time/               |          |
# |    episodes         | 96       |
# |    fps              | 1511     |
# |    time_elapsed     | 63       |
# |    total timesteps  | 96000    |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 23987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 100      |
# |    fps              | 1497     |
# |    time_elapsed     | 66       |
# |    total timesteps  | 100000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 24987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 104      |
# |    fps              | 1488     |
# |    time_elapsed     | 69       |
# |    total timesteps  | 104000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 25987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 108      |
# |    fps              | 1478     |
# |    time_elapsed     | 73       |
# |    total timesteps  | 108000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 26987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 112      |
# |    fps              | 1468     |
# |    time_elapsed     | 76       |
# |    total timesteps  | 112000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 27987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 116      |
# |    fps              | 1457     |
# |    time_elapsed     | 79       |
# |    total timesteps  | 116000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 28987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 120      |
# |    fps              | 1451     |
# |    time_elapsed     | 82       |
# |    total timesteps  | 120000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 29987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 124      |
# |    fps              | 1445     |
# |    time_elapsed     | 85       |
# |    total timesteps  | 124000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 30987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 128      |
# |    fps              | 1440     |
# |    time_elapsed     | 88       |
# |    total timesteps  | 128000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 31987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 132      |
# |    fps              | 1435     |
# |    time_elapsed     | 91       |
# |    total timesteps  | 132000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 32987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 136      |
# |    fps              | 1430     |
# |    time_elapsed     | 95       |
# |    total timesteps  | 136000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 33987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 140      |
# |    fps              | 1426     |
# |    time_elapsed     | 98       |
# |    total timesteps  | 140000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 34987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 144      |
# |    fps              | 1422     |
# |    time_elapsed     | 101      |
# |    total timesteps  | 144000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 35987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 148      |
# |    fps              | 1418     |
# |    time_elapsed     | 104      |
# |    total timesteps  | 148000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 36987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 152      |
# |    fps              | 1412     |
# |    time_elapsed     | 107      |
# |    total timesteps  | 152000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 37987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 156      |
# |    fps              | 1408     |
# |    time_elapsed     | 110      |
# |    total timesteps  | 156000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 38987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 160      |
# |    fps              | 1401     |
# |    time_elapsed     | 114      |
# |    total timesteps  | 160000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 39987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 164      |
# |    fps              | 1398     |
# |    time_elapsed     | 117      |
# |    total timesteps  | 164000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 40987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 168      |
# |    fps              | 1395     |
# |    time_elapsed     | 120      |
# |    total timesteps  | 168000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 41987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 172      |
# |    fps              | 1391     |
# |    time_elapsed     | 123      |
# |    total timesteps  | 172000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 42987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 176      |
# |    fps              | 1388     |
# |    time_elapsed     | 126      |
# |    total timesteps  | 176000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 43987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 180      |
# |    fps              | 1386     |
# |    time_elapsed     | 129      |
# |    total timesteps  | 180000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 44987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 184      |
# |    fps              | 1384     |
# |    time_elapsed     | 132      |
# |    total timesteps  | 184000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 45987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 188      |
# |    fps              | 1382     |
# |    time_elapsed     | 136      |
# |    total timesteps  | 188000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 46987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 192      |
# |    fps              | 1379     |
# |    time_elapsed     | 139      |
# |    total timesteps  | 192000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 47987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 196      |
# |    fps              | 1377     |
# |    time_elapsed     | 142      |
# |    total timesteps  | 196000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 48987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 200      |
# |    fps              | 1374     |
# |    time_elapsed     | 145      |
# |    total timesteps  | 200000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 49987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 204      |
# |    fps              | 1371     |
# |    time_elapsed     | 148      |
# |    total timesteps  | 204000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 50987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 208      |
# |    fps              | 1369     |
# |    time_elapsed     | 151      |
# |    total timesteps  | 208000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 51987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 212      |
# |    fps              | 1367     |
# |    time_elapsed     | 155      |
# |    total timesteps  | 212000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 52987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 216      |
# |    fps              | 1365     |
# |    time_elapsed     | 158      |
# |    total timesteps  | 216000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 53987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 220      |
# |    fps              | 1363     |
# |    time_elapsed     | 161      |
# |    total timesteps  | 220000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 54987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 224      |
# |    fps              | 1361     |
# |    time_elapsed     | 164      |
# |    total timesteps  | 224000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 55987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 228      |
# |    fps              | 1358     |
# |    time_elapsed     | 167      |
# |    total timesteps  | 228000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 56987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 232      |
# |    fps              | 1356     |
# |    time_elapsed     | 171      |
# |    total timesteps  | 232000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 57987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 236      |
# |    fps              | 1354     |
# |    time_elapsed     | 174      |
# |    total timesteps  | 236000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 58987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 240      |
# |    fps              | 1352     |
# |    time_elapsed     | 177      |
# |    total timesteps  | 240000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 59987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 244      |
# |    fps              | 1350     |
# |    time_elapsed     | 180      |
# |    total timesteps  | 244000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 60987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 248      |
# |    fps              | 1349     |
# |    time_elapsed     | 183      |
# |    total timesteps  | 248000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 61987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 252      |
# |    fps              | 1347     |
# |    time_elapsed     | 187      |
# |    total timesteps  | 252000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 62987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 256      |
# |    fps              | 1346     |
# |    time_elapsed     | 190      |
# |    total timesteps  | 256000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 63987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 260      |
# |    fps              | 1344     |
# |    time_elapsed     | 193      |
# |    total timesteps  | 260000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 64987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 264      |
# |    fps              | 1344     |
# |    time_elapsed     | 196      |
# |    total timesteps  | 264000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 65987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 268      |
# |    fps              | 1342     |
# |    time_elapsed     | 199      |
# |    total timesteps  | 268000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 66987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 272      |
# |    fps              | 1341     |
# |    time_elapsed     | 202      |
# |    total timesteps  | 272000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 67987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 276      |
# |    fps              | 1339     |
# |    time_elapsed     | 205      |
# |    total timesteps  | 276000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 68987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 280      |
# |    fps              | 1338     |
# |    time_elapsed     | 209      |
# |    total timesteps  | 280000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 69987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 284      |
# |    fps              | 1336     |
# |    time_elapsed     | 212      |
# |    total timesteps  | 284000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 70987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 288      |
# |    fps              | 1334     |
# |    time_elapsed     | 215      |
# |    total timesteps  | 288000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 71987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 292      |
# |    fps              | 1333     |
# |    time_elapsed     | 219      |
# |    total timesteps  | 292000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 72987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 296      |
# |    fps              | 1332     |
# |    time_elapsed     | 222      |
# |    total timesteps  | 296000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 73987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 300      |
# |    fps              | 1331     |
# |    time_elapsed     | 225      |
# |    total timesteps  | 300000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 74987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 304      |
# |    fps              | 1330     |
# |    time_elapsed     | 228      |
# |    total timesteps  | 304000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 75987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 308      |
# |    fps              | 1329     |
# |    time_elapsed     | 231      |
# |    total timesteps  | 308000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 76987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 312      |
# |    fps              | 1328     |
# |    time_elapsed     | 234      |
# |    total timesteps  | 312000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 77987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 316      |
# |    fps              | 1327     |
# |    time_elapsed     | 237      |
# |    total timesteps  | 316000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 78987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 320      |
# |    fps              | 1326     |
# |    time_elapsed     | 241      |
# |    total timesteps  | 320000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 79987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 324      |
# |    fps              | 1326     |
# |    time_elapsed     | 244      |
# |    total timesteps  | 324000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 80987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 328      |
# |    fps              | 1325     |
# |    time_elapsed     | 247      |
# |    total timesteps  | 328000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 81987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 332      |
# |    fps              | 1324     |
# |    time_elapsed     | 250      |
# |    total timesteps  | 332000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 82987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 336      |
# |    fps              | 1323     |
# |    time_elapsed     | 253      |
# |    total timesteps  | 336000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 83987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 340      |
# |    fps              | 1322     |
# |    time_elapsed     | 257      |
# |    total timesteps  | 340000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 84987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 344      |
# |    fps              | 1321     |
# |    time_elapsed     | 260      |
# |    total timesteps  | 344000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 85987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 348      |
# |    fps              | 1320     |
# |    time_elapsed     | 263      |
# |    total timesteps  | 348000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 86987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 352      |
# |    fps              | 1320     |
# |    time_elapsed     | 266      |
# |    total timesteps  | 352000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 87987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 356      |
# |    fps              | 1319     |
# |    time_elapsed     | 269      |
# |    total timesteps  | 356000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 88987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 360      |
# |    fps              | 1318     |
# |    time_elapsed     | 272      |
# |    total timesteps  | 360000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 89987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 364      |
# |    fps              | 1317     |
# |    time_elapsed     | 276      |
# |    total timesteps  | 364000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 90987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 368      |
# |    fps              | 1317     |
# |    time_elapsed     | 279      |
# |    total timesteps  | 368000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 91987    |
# ----------------------------------
# ----------------------------------
# | rollout/            |          |
# |    exploration rate | 0.05     |
# | time/               |          |
# |    episodes         | 372      |
# |    fps              | 1316     |
# |    time_elapsed     | 282      |
# |    total timesteps  | 372000   |
# | train/              |          |
# |    learning_rate    | 0.0001   |
# |    n_updates        | 92987    |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-65-1b3a1a85e767> in <module>
#       4                batch_size=8,
#       5                verbose=1)
# ----> 6 dqnAgent.learn(total_timesteps=1000000)
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/dqn/dqn.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     229             tb_log_name=tb_log_name,
#     230             eval_log_path=eval_log_path,
# --> 231             reset_num_timesteps=reset_num_timesteps,
#     232         )
#     233
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     251                 learning_starts=self.learning_starts,
#     252                 replay_buffer=self.replay_buffer,
# --> 253                 log_interval=log_interval,
#     254             )
#     255
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/common/off_policy_algorithm.py in collect_rollouts(self, env, callback, n_episodes, n_steps, action_noise, learning_starts, replay_buffer, log_interval)
#     398
#     399                 # Select action randomly or according to policy
# --> 400                 action, buffer_action = self._sample_action(learning_starts, action_noise)
#     401
#     402                 # Rescale and perform action
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/common/off_policy_algorithm.py in _sample_action(self, learning_starts, action_noise)
#     299             # we assume that the policy uses tanh to scale the action
#     300             # We use non-deterministic action in the case of SAC, for TD3, it does not matter
# --> 301             unscaled_action, _ = self.predict(self._last_obs, deterministic=False)
#     302
#     303         # Rescale the action from [low, high] to [-1, 1]
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/dqn/dqn.py in predict(self, observation, state, mask, deterministic)
#     204             action = np.array([self.action_space.sample() for _ in range(n_batch)])
#     205         else:
# --> 206             action, state = self.policy.predict(observation, state, mask, deterministic)
#     207         return action, state
#     208
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/common/policies.py in predict(self, observation, state, mask, deterministic)
#     250         observation = th.as_tensor(observation).to(self.device)
#     251         with th.no_grad():
# --> 252             actions = self._predict(observation, deterministic=deterministic)
#     253         # Convert to numpy
#     254         actions = actions.cpu().numpy()
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/dqn/policies.py in _predict(self, obs, deterministic)
#     175
#     176     def _predict(self, obs: th.Tensor, deterministic: bool = True) -> th.Tensor:
# --> 177         return self.q_net._predict(obs, deterministic=deterministic)
#     178
#     179     def _get_data(self) -> Dict[str, Any]:
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/dqn/policies.py in _predict(self, observation, deterministic)
#      63
#      64     def _predict(self, observation: th.Tensor, deterministic: bool = True) -> th.Tensor:
# ---> 65         q_values = self.forward(observation)
#      66         # Greedy action
#      67         action = q_values.argmax(dim=1).reshape(-1)
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/dqn/policies.py in forward(self, obs)
#      60         :return: (th.Tensor) The estimated Q-Value for each action.
#      61         """
# ---> 62         return self.q_net(self.extract_features(obs))
#      63
#      64     def _predict(self, observation: th.Tensor, deterministic: bool = True) -> th.Tensor:
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      89
#      90     def forward(self, input: Tensor) -> Tensor:
# ---> 91         return F.linear(input, self.weight, self.bias)
#      92
#      93     def extra_repr(self) -> str:
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1672     if input.dim() == 2 and bias is not None:
#    1673         # fused op is marginally faster
# -> 1674         ret = torch.addmm(bias, input, weight.t())
#    1675     else:
#    1676         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
n = 3
end_t = 1000000
env =  RLSwitchEnv(n,end_t, lambdaMatrix = None)
a2cAgent = A2C('MlpPolicy', env,n_steps=5, verbose=1)
a2cAgent.learn(total_timesteps=1000000)
# Out:
# Using cuda device
# Wrapping the env in a DummyVecEnv.
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 100       |
# |    time_elapsed       | 0         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -1.7      |
# |    explained_variance | -1.64e+08 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -263      |
# |    value_loss         | 2.51e+04  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 789      |
# |    iterations         | 200      |
# |    time_elapsed       | 1        |
# |    total_timesteps    | 1000     |
# | train/                |          |
# |    entropy_loss       | -1.67    |
# |    explained_variance | -1.2e+11 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 199      |
# |    policy_loss        | -709     |
# |    value_loss         | 1.23e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 788       |
# |    iterations         | 300       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -1.25     |
# |    explained_variance | -1.29e+13 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -626      |
# |    value_loss         | 4.88e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 791       |
# |    iterations         | 400       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | -3e+15    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -2.72e+03 |
# |    value_loss         | 2.38e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 791       |
# |    iterations         | 500       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -1.7      |
# |    explained_variance | -9.96e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | -2.78e+03 |
# |    value_loss         | 3.24e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 790       |
# |    iterations         | 600       |
# |    time_elapsed       | 3         |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -1.77     |
# |    explained_variance | -3.59e+13 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | -2.42e+03 |
# |    value_loss         | 2.55e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 791       |
# |    iterations         | 700       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -1.78     |
# |    explained_variance | -4e+12    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -1.53e+03 |
# |    value_loss         | 9.9e+05   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 791      |
# |    iterations         | 800      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -1.67    |
# |    explained_variance | -4.2e+10 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -626     |
# |    value_loss         | 1.81e+05 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 791      |
# |    iterations         | 900      |
# |    time_elapsed       | 5        |
# |    total_timesteps    | 4500     |
# | train/                |          |
# |    entropy_loss       | -1.63    |
# |    explained_variance | -3.9e+12 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 899      |
# |    policy_loss        | -869     |
# |    value_loss         | 1.64e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 792       |
# |    iterations         | 1000      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | -1.24e+15 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -1.58e+03 |
# |    value_loss         | 1.22e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 792       |
# |    iterations         | 1100      |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -1.47     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -1.38e+03 |
# |    value_loss         | 4.22e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 791       |
# |    iterations         | 1200      |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -1.32     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -3.45e+03 |
# |    value_loss         | 9.25e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 792       |
# |    iterations         | 1300      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -4.38e+03 |
# |    value_loss         | 1.38e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 793       |
# |    iterations         | 1400      |
# |    time_elapsed       | 8         |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -3.98e+03 |
# |    value_loss         | 1.9e+07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 793       |
# |    iterations         | 1500      |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -1.45     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -4.54e+03 |
# |    value_loss         | 2.36e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 1600      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -1.73     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -7.78e+03 |
# |    value_loss         | 2.39e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 1700      |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -1.61     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -6.61e+03 |
# |    value_loss         | 2.23e+07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 794      |
# |    iterations         | 1800     |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -1.65    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -7.4e+03 |
# |    value_loss         | 2.27e+07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 1900      |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -1.56     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | -6.99e+03 |
# |    value_loss         | 2.11e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 2000      |
# |    time_elapsed       | 12        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -6.44e+03 |
# |    value_loss         | 2.31e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 2100      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -1.59     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -9.02e+03 |
# |    value_loss         | 2.88e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 2200      |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -1.58     |
# |    explained_variance | -1.1e+17  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -1.06e+04 |
# |    value_loss         | 3.59e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 2300      |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 11500     |
# | train/                |           |
# |    entropy_loss       | -1.48     |
# |    explained_variance | -1.32e+17 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2299      |
# |    policy_loss        | -8.66e+03 |
# |    value_loss         | 4.29e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 2400      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -1.32     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | -1.21e+04 |
# |    value_loss         | 4.69e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 2500      |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -1.59     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -5.72e+03 |
# |    value_loss         | 4.37e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 2600      |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -1.3      |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -3.06e+03 |
# |    value_loss         | 3.73e+07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 794      |
# |    iterations         | 2700     |
# |    time_elapsed       | 16       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -1.58    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -8.4e+03 |
# |    value_loss         | 2.97e+07 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 2800      |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -1.6      |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | -5.87e+03 |
# |    value_loss         | 2.5e+07   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 2900      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -1.65     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -8.46e+03 |
# |    value_loss         | 1.97e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 3000      |
# |    time_elapsed       | 18        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -1.62     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | -6.71e+03 |
# |    value_loss         | 1.28e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 3100      |
# |    time_elapsed       | 19        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -1.59     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | -4.76e+03 |
# |    value_loss         | 8.61e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 3200      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -1.76     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -3.38e+03 |
# |    value_loss         | 4.37e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 3300      |
# |    time_elapsed       | 20        |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -1.62     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -1.98e+03 |
# |    value_loss         | 2.17e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 3400      |
# |    time_elapsed       | 21        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -1.62     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -1.58e+03 |
# |    value_loss         | 1.12e+06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 795      |
# |    iterations         | 3500     |
# |    time_elapsed       | 22       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -1.59    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | -1.7e+03 |
# |    value_loss         | 1.02e+06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 3600      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -1.73     |
# |    explained_variance | -1.96e+14 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -1.14e+03 |
# |    value_loss         | 5.61e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 3700      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -1.7      |
# |    explained_variance | -3.02e+14 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | -818      |
# |    value_loss         | 3.18e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 794       |
# |    iterations         | 3800      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -1.55     |
# |    explained_variance | -6.97e+13 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -590      |
# |    value_loss         | 2.37e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 3900      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -1.62     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -1.35e+03 |
# |    value_loss         | 7.08e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4000      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -1.68     |
# |    explained_variance | -3.67e+14 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | -1.32e+03 |
# |    value_loss         | 1.05e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4100      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 20500     |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4099      |
# |    policy_loss        | -2.53e+03 |
# |    value_loss         | 2.65e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4200      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -1.65     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -2.92e+03 |
# |    value_loss         | 5.01e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4300      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 21500     |
# | train/                |           |
# |    entropy_loss       | -1.6      |
# |    explained_variance | -5.02e+15 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4299      |
# |    policy_loss        | -4.01e+03 |
# |    value_loss         | 6.56e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4400      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -1.5      |
# |    explained_variance | -5.6e+15  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -4.75e+03 |
# |    value_loss         | 7.31e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4500      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -1.56     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | -4.79e+03 |
# |    value_loss         | 5.25e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4600      |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -1.58     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | -3.45e+03 |
# |    value_loss         | 4.83e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4700      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 23500     |
# | train/                |           |
# |    entropy_loss       | -1.67     |
# |    explained_variance | -3.82e+15 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4699      |
# |    policy_loss        | -3.61e+03 |
# |    value_loss         | 4.98e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4800      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -1.72     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | -3.43e+03 |
# |    value_loss         | 5.62e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 4900      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 24500     |
# | train/                |           |
# |    entropy_loss       | -1.73     |
# |    explained_variance | -3.96e+15 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4899      |
# |    policy_loss        | -3.02e+03 |
# |    value_loss         | 5.18e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 795       |
# |    iterations         | 5000      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 25000     |
# | train/                |           |
# |    entropy_loss       | -1.67     |
# |    explained_variance | -4.06e+15 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4999      |
# |    policy_loss        | -3.75e+03 |
# |    value_loss         | 5.28e+06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 795      |
# |    iterations         | 5100     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -1.71    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | -4.5e+03 |
# |    value_loss         | 5.48e+06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 5200      |
# |    time_elapsed       | 32        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -1.68     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -3.17e+03 |
# |    value_loss         | 5.98e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 5300      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -1.22     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | -4.42e+03 |
# |    value_loss         | 4.97e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 5400      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -1.41     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -4.01e+03 |
# |    value_loss         | 9.07e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 5500      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -1.72     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | -4.37e+03 |
# |    value_loss         | 9.57e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 5600      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 28000     |
# | train/                |           |
# |    entropy_loss       | -1.71     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5599      |
# |    policy_loss        | -4.23e+03 |
# |    value_loss         | 5.55e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 5700      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 28500     |
# | train/                |           |
# |    entropy_loss       | -1.53     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5699      |
# |    policy_loss        | -1.99e+03 |
# |    value_loss         | 2.98e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 5800      |
# |    time_elapsed       | 36        |
# |    total_timesteps    | 29000     |
# | train/                |           |
# |    entropy_loss       | -1.71     |
# |    explained_variance | -8.26e+14 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5799      |
# |    policy_loss        | -2.18e+03 |
# |    value_loss         | 2.58e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 5900      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -1.76     |
# |    explained_variance | -6.34e+14 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -1.82e+03 |
# |    value_loss         | 1.32e+06  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 6000     |
# |    time_elapsed       | 37       |
# |    total_timesteps    | 30000    |
# | train/                |          |
# |    entropy_loss       | -1.72    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5999     |
# |    policy_loss        | -1.2e+03 |
# |    value_loss         | 5.22e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 6100      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -1.7      |
# |    explained_variance | -6.59e+13 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -663      |
# |    value_loss         | 2.05e+05  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 6200      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -1.67     |
# |    explained_variance | -3.32e+13 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -346      |
# |    value_loss         | 3.45e+04  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 6300      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -1.66     |
# |    explained_variance | -8.58e+12 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -288      |
# |    value_loss         | 2.78e+04  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 6400     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 32000    |
# | train/                |          |
# |    entropy_loss       | -1.66    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6399     |
# |    policy_loss        | -196     |
# |    value_loss         | 1.97e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 6500     |
# |    time_elapsed       | 40       |
# |    total_timesteps    | 32500    |
# | train/                |          |
# |    entropy_loss       | -1.6     |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6499     |
# |    policy_loss        | -190     |
# |    value_loss         | 2.22e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 6600     |
# |    time_elapsed       | 41       |
# |    total_timesteps    | 33000    |
# | train/                |          |
# |    entropy_loss       | -1.55    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6599     |
# |    policy_loss        | -236     |
# |    value_loss         | 4.13e+04 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 6700     |
# |    time_elapsed       | 42       |
# |    total_timesteps    | 33500    |
# | train/                |          |
# |    entropy_loss       | -1.57    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6699     |
# |    policy_loss        | -130     |
# |    value_loss         | 1.36e+04 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 6800      |
# |    time_elapsed       | 42        |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -1.55     |
# |    explained_variance | -1.73e+06 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -18.4     |
# |    value_loss         | 93.9      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 6900     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 34500    |
# | train/                |          |
# |    entropy_loss       | -1.42    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6899     |
# |    policy_loss        | -96.9    |
# |    value_loss         | 5.24e+03 |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 7000     |
# |    time_elapsed       | 43       |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -1.14    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | -221     |
# |    value_loss         | 4.01e+05 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 7100      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -0.948    |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -1.79e+03 |
# |    value_loss         | 1.29e+06  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 7200      |
# |    time_elapsed       | 45        |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -1.13     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -1.14e+03 |
# |    value_loss         | 3.9e+06   |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 7300     |
# |    time_elapsed       | 45       |
# |    total_timesteps    | 36500    |
# | train/                |          |
# |    entropy_loss       | -1.56    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7299     |
# |    policy_loss        | -5.6e+03 |
# |    value_loss         | 8.97e+06 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 7400      |
# |    time_elapsed       | 46        |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -1.36     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | -6.85e+03 |
# |    value_loss         | 1.32e+07  |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 7500     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 37500    |
# | train/                |          |
# |    entropy_loss       | -0.798   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7499     |
# |    policy_loss        | -981     |
# |    value_loss         | 2.5e+07  |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 796      |
# |    iterations         | 7600     |
# |    time_elapsed       | 47       |
# |    total_timesteps    | 38000    |
# | train/                |          |
# |    entropy_loss       | -0.634   |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 7599     |
# |    policy_loss        | -936     |
# |    value_loss         | 4.5e+07  |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 7700      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -1.54     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -1.21e+04 |
# |    value_loss         | 5.68e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 7800      |
# |    time_elapsed       | 48        |
# |    total_timesteps    | 39000     |
# | train/                |           |
# |    entropy_loss       | -1.55     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7799      |
# |    policy_loss        | -1.11e+04 |
# |    value_loss         | 5.53e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 7900      |
# |    time_elapsed       | 49        |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -0.688    |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | -1.21e+03 |
# |    value_loss         | 6.05e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8000      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 40000     |
# | train/                |           |
# |    entropy_loss       | -1.38     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7999      |
# |    policy_loss        | -1.24e+04 |
# |    value_loss         | 8.61e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8100      |
# |    time_elapsed       | 50        |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -1.08     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | -8.35e+03 |
# |    value_loss         | 1.01e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8200      |
# |    time_elapsed       | 51        |
# |    total_timesteps    | 41000     |
# | train/                |           |
# |    entropy_loss       | -1.3      |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8199      |
# |    policy_loss        | -6.62e+03 |
# |    value_loss         | 1.24e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8300      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 41500     |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8299      |
# |    policy_loss        | -1.93e+04 |
# |    value_loss         | 1.39e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8400      |
# |    time_elapsed       | 52        |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -1.6      |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | -1.23e+04 |
# |    value_loss         | 1.39e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8500      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -1.22     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | -1.56e+04 |
# |    value_loss         | 1.27e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8600      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -1.21     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | -1.02e+04 |
# |    value_loss         | 1.16e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8700      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -1.47     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | -1.23e+04 |
# |    value_loss         | 1.11e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8800      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -1.32     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -2.88e+04 |
# |    value_loss         | 1.03e+08  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 8900      |
# |    time_elapsed       | 55        |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -1.49     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | -1.08e+04 |
# |    value_loss         | 9.34e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 9000      |
# |    time_elapsed       | 56        |
# |    total_timesteps    | 45000     |
# | train/                |           |
# |    entropy_loss       | -1.34     |
# |    explained_variance | -1.78e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8999      |
# |    policy_loss        | -1.59e+04 |
# |    value_loss         | 9.29e+07  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 796       |
# |    iterations         | 9100      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -1.3      |
# ...
# |    entropy_loss       | -1.69    |
# |    explained_variance | nan      |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 73099    |
# |    policy_loss        | -1.5e+05 |
# |    value_loss         | 8.49e+09 |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 73200     |
# |    time_elapsed       | 472       |
# |    total_timesteps    | 366000    |
# | train/                |           |
# |    entropy_loss       | -1.44     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73199     |
# |    policy_loss        | -7.47e+04 |
# |    value_loss         | 8.44e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 73300     |
# |    time_elapsed       | 473       |
# |    total_timesteps    | 366500    |
# | train/                |           |
# |    entropy_loss       | -1.35     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73299     |
# |    policy_loss        | -1.74e+05 |
# |    value_loss         | 8.4e+09   |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 73400     |
# |    time_elapsed       | 473       |
# |    total_timesteps    | 367000    |
# | train/                |           |
# |    entropy_loss       | -1.48     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73399     |
# |    policy_loss        | -1.14e+05 |
# |    value_loss         | 8.33e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 73500     |
# |    time_elapsed       | 474       |
# |    total_timesteps    | 367500    |
# | train/                |           |
# |    entropy_loss       | -1.56     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73499     |
# |    policy_loss        | -1.78e+05 |
# |    value_loss         | 8.26e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 73600     |
# |    time_elapsed       | 474       |
# |    total_timesteps    | 368000    |
# | train/                |           |
# |    entropy_loss       | -1.29     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73599     |
# |    policy_loss        | -1.11e+05 |
# |    value_loss         | 8.27e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 73700     |
# |    time_elapsed       | 475       |
# |    total_timesteps    | 368500    |
# | train/                |           |
# |    entropy_loss       | -1.39     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73699     |
# |    policy_loss        | -1.31e+05 |
# |    value_loss         | 8.27e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 73800     |
# |    time_elapsed       | 476       |
# |    total_timesteps    | 369000    |
# | train/                |           |
# |    entropy_loss       | -0.803    |
# |    explained_variance | -2.5e+16  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73799     |
# |    policy_loss        | -8.14e+04 |
# |    value_loss         | 8.35e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 73900     |
# |    time_elapsed       | 476       |
# |    total_timesteps    | 369500    |
# | train/                |           |
# |    entropy_loss       | -0.698    |
# |    explained_variance | -2.54e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73899     |
# |    policy_loss        | -1.55e+04 |
# |    value_loss         | 8.49e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74000     |
# |    time_elapsed       | 477       |
# |    total_timesteps    | 370000    |
# | train/                |           |
# |    entropy_loss       | -0.624    |
# |    explained_variance | -2.59e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 73999     |
# |    policy_loss        | -1.34e+04 |
# |    value_loss         | 8.65e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74100     |
# |    time_elapsed       | 478       |
# |    total_timesteps    | 370500    |
# | train/                |           |
# |    entropy_loss       | -0.425    |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74099     |
# |    policy_loss        | -5.13e+04 |
# |    value_loss         | 8.85e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74200     |
# |    time_elapsed       | 478       |
# |    total_timesteps    | 371000    |
# | train/                |           |
# |    entropy_loss       | -0.57     |
# |    explained_variance | -2.72e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74199     |
# |    policy_loss        | -4.69e+04 |
# |    value_loss         | 9.09e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74300     |
# |    time_elapsed       | 479       |
# |    total_timesteps    | 371500    |
# | train/                |           |
# |    entropy_loss       | -0.622    |
# |    explained_variance | -2.77e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74299     |
# |    policy_loss        | -5.42e+04 |
# |    value_loss         | 9.25e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74400     |
# |    time_elapsed       | 480       |
# |    total_timesteps    | 372000    |
# | train/                |           |
# |    entropy_loss       | -1.09     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74399     |
# |    policy_loss        | -7.13e+04 |
# |    value_loss         | 9.45e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74500     |
# |    time_elapsed       | 480       |
# |    total_timesteps    | 372500    |
# | train/                |           |
# |    entropy_loss       | -1.31     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74499     |
# |    policy_loss        | -1.38e+05 |
# |    value_loss         | 9.51e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74600     |
# |    time_elapsed       | 481       |
# |    total_timesteps    | 373000    |
# | train/                |           |
# |    entropy_loss       | -1.31     |
# |    explained_variance | -2.87e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74599     |
# |    policy_loss        | -9.23e+04 |
# |    value_loss         | 9.61e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74700     |
# |    time_elapsed       | 482       |
# |    total_timesteps    | 373500    |
# | train/                |           |
# |    entropy_loss       | -1.06     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74699     |
# |    policy_loss        | -7.98e+04 |
# |    value_loss         | 9.73e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74800     |
# |    time_elapsed       | 482       |
# |    total_timesteps    | 374000    |
# | train/                |           |
# |    entropy_loss       | -1.15     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74799     |
# |    policy_loss        | -9.06e+04 |
# |    value_loss         | 9.85e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 74900     |
# |    time_elapsed       | 483       |
# |    total_timesteps    | 374500    |
# | train/                |           |
# |    entropy_loss       | -1.05     |
# |    explained_variance | -2.99e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74899     |
# |    policy_loss        | -7.92e+04 |
# |    value_loss         | 1e+10     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 75000     |
# |    time_elapsed       | 484       |
# |    total_timesteps    | 375000    |
# | train/                |           |
# |    entropy_loss       | -1.23     |
# |    explained_variance | -3.04e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 74999     |
# |    policy_loss        | -1.04e+05 |
# |    value_loss         | 1.01e+10  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 75100     |
# |    time_elapsed       | 484       |
# |    total_timesteps    | 375500    |
# | train/                |           |
# |    entropy_loss       | -1.53     |
# |    explained_variance | -3.04e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 75099     |
# |    policy_loss        | -9.89e+04 |
# |    value_loss         | 1.02e+10  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 75200     |
# |    time_elapsed       | 485       |
# |    total_timesteps    | 376000    |
# | train/                |           |
# |    entropy_loss       | -1.67     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 75199     |
# |    policy_loss        | -1.63e+05 |
# |    value_loss         | 1.01e+10  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 75300     |
# |    time_elapsed       | 486       |
# |    total_timesteps    | 376500    |
# | train/                |           |
# |    entropy_loss       | -1.7      |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 75299     |
# |    policy_loss        | -1.58e+05 |
# |    value_loss         | 1e+10     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 75400     |
# |    time_elapsed       | 486       |
# |    total_timesteps    | 377000    |
# | train/                |           |
# |    entropy_loss       | -1.68     |
# |    explained_variance | nan       |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 75399     |
# |    policy_loss        | -1.45e+05 |
# |    value_loss         | 9.89e+09  |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 774       |
# |    iterations         | 75500     |
# |    time_elapsed       | 487       |
# |    total_timesteps    | 377500    |
# | train/                |           |
# |    entropy_loss       | -1.56     |
# |    explained_variance | -2.91e+16 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 75499     |
# |    policy_loss        | -1.37e+05 |
# |    value_loss         | 9.74e+09  |
# -------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-103-88a3ee3f5f55> in <module>
#       3 env =  RLSwitchEnv(n,end_t, lambdaMatrix = None)
#       4 a2cAgent = A2C('MlpPolicy', env,n_steps=5, verbose=1)
# ----> 5 a2cAgent.learn(total_timesteps=1000000)
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/a2c/a2c.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     190             tb_log_name=tb_log_name,
#     191             eval_log_path=eval_log_path,
# --> 192             reset_num_timesteps=reset_num_timesteps,
#     193         )
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, eval_env, eval_freq, n_eval_episodes, tb_log_name, eval_log_path, reset_num_timesteps)
#     233                 logger.dump(step=self.num_timesteps)
#     234
# --> 235             self.train()
#     236
#     237         callback.on_training_end()
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/a2c/a2c.py in train(self)
#     126
#     127             # TODO: avoid second computation of everything because of the gradient
# --> 128             values, log_prob, entropy = self.policy.evaluate_actions(rollout_data.observations, actions)
#     129             values = values.flatten()
#     130
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/stable_baselines3/common/policies.py in evaluate_actions(self, obs, actions)
#     582         distribution = self._get_action_dist_from_latent(latent_pi, latent_sde)
#     583         log_prob = distribution.log_prob(actions)
# --> 584         values = self.value_net(latent_vf)
#     585         return values, log_prob, distribution.entropy()
#     586
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     720             result = self._slow_forward(*input, **kwargs)
#     721         else:
# --> 722             result = self.forward(*input, **kwargs)
#     723         for hook in itertools.chain(
#     724                 _global_forward_hooks.values(),
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/torch/nn/modules/linear.py in forward(self, input)
#      89
#      90     def forward(self, input: Tensor) -> Tensor:
# ---> 91         return F.linear(input, self.weight, self.bias)
#      92
#      93     def extra_repr(self) -> str:
#
# ~/anaconda3/envs/RLSwitching/lib/python3.7/site-packages/torch/nn/functional.py in linear(input, weight, bias)
#    1672     if input.dim() == 2 and bias is not None:
#    1673         # fused op is marginally faster
# -> 1674         ret = torch.addmm(bias, input, weight.t())
#    1675     else:
#    1676         output = input.matmul(weight.t())
#
# KeyboardInterrupt:

# %%
{}# Random Environment
n = 3 # nxn
end_t = 1000 # number of time steps to end an episode after
env = RLSwitchEnv(n,end_t, lambdaMatrix = None)
# test settings

tests = 10
rewardsRandom = np.zeros((tests,end_t))


for i in tqdm(range(0,tests)):
    env.reset()
    for j in range(0,end_t):
        action = env.action_space.sample()
        observation, reward, done, info = env.step(action)
        rewardsRandom[i][j] = reward
        if done:
            env.reset()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
# maxWeight Environment
n = 3 # nxn
end_t = 1000 # number of time steps to end an episode after
env = RLSwitchEnv(n,end_t, lambdaMatrix = None)
# test settings

tests = 10
rewardsMaxWeight = np.zeros((tests,end_t))

maxWeightAgent = maxWeight(env)

for i in tqdm(range(0,tests)):
    env.reset()
    for j in range(0,end_t):
        action = maxWeightAgent.act()
        observation, reward, done, info = env.step(action)
        rewardsMaxWeight[i][j] = reward
        if done:
            env.reset()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
# a2c Environment
n = 3 # nxn
end_t = 1000 # number of time steps to end an episode after
env = RLSwitchEnv(n,end_t, lambdaMatrix = None)
# test settings

tests = 10
rewardsa2c = np.zeros((tests,end_t))

for i in tqdm(range(0,tests)):
    observation = env.reset()
    for j in range(0,end_t):
        action,_ = a2cAgent.predict(observation)
        observation, reward, done, info = env.step(action)
        rewardsa2c[i][j] = reward
        if done:
            env.reset()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
# dqn Environment
n = 3 # nxn
end_t = 1000 # number of time steps to end an episode after
env = RLSwitchEnv(n,end_t, lambdaMatrix = None)
# test settings

tests = 10
rewardsDQN = np.zeros((tests,end_t))

for i in tqdm(range(0,tests)):
    observation = env.reset()
    for j in range(0,end_t):
        action,_ = dqnAgent.predict(observation)
        if hasattr(action, "__len__"):
            action = np.random.choice(action)
        observation, reward, done, info = env.step(action)
        rewardsDQN[i][j] = reward
        if done:
            env.reset()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
# ppo Environment
n = 3 # nxn
end_t = 1000 # number of time steps to end an episode after
env = RLSwitchEnv(n,end_t, lambdaMatrix = None)
# test settings

tests = 10
rewardsPPO = np.zeros((tests,end_t))

for i in tqdm(range(0,tests)):
    observation = env.reset()
    for j in range(0,end_t):
        action,_ = ppoAgent.predict(observation)
        if hasattr(action, "__len__"):
            action = np.random.choice(action)
        observation, reward, done, info = env.step(action)
        rewardsPPO[i][j] = reward
        if done:
            env.reset()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=10.0), HTML(value='')))

# %%
avgRandom = np.average(rewardsRandom,axis=1)
avgDQN = np.average(rewardsDQN,axis=1)
avga2c = np.average(rewardsa2c,axis=1)
avgPPO = np.average(rewardsPPO,axis=1)
avgmaxWeight = np.average(rewardsMaxWeight,axis=1)

# %%
plt.plot(avgDQN)
plt.plot(avga2c)
plt.plot(avgPPO)
plt.plot(avgmaxWeight)
plt.plot(avgRandom)
plt.legend([
            "DQN"
            ,"a2c"
            ,"avgPPO"
            ,'maxWeight'
            ,'Random'
           ]
          )
plt.show()
